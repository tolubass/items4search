# %% [markdown]
#  # Introduction
#  This project shows how the price of an item can be searched instead of writing the price on the body of such item. it could also apply to many items in the store or supermarket just to make work easier and faster for customers and  sales person in charge. items in the store are being grouped into different categories. Lastly, all items can also be seen in the last group if a category is not being cleared enough for the sales person in charge.
#
#  By inputing the name of the item, it gives the direct price of the item only

# %%
print("Welcome to tolubass supermarket")
print("SEARCH THE PRICE OF ANY ITEM")


print("a.clas Snacks")
print("b.clas Beverages")
print("c.clas Drinks and wines")
print("d.clas Drugs")
print("e.SEARCH ALL ")

class_search = input("Enter the class/category of the item:(a/b/c/d/e):")

if class_search == "a":
    print("The class snacks available are;")
    print('\nmeat_pie\nbuns\nsamosa\ndoughnut\npuff_puff\npuff_puff\nbread\nsharwarma')
    item_name = input("Enter item_name:")
    items_in_store = ["meat_pie", "egg_roll", "buns", "samosa", "doughnut", "puff_puff", "bread", "sharwarma"]
    print("price in #")
    price_of_items = [100, 233, 123, 567, 870, 545, 1000, 1900]
    if item_name == items_in_store[0] :
        print(price_of_items[0])
    elif item_name == items_in_store[1]:
        print(price_of_items[1])
    elif item_name == items_in_store[2]:
        print(price_of_items[2])
    elif item_name == items_in_store[3]:
        print(price_of_items[3])
    elif item_name == items_in_store[4]:
        print(price_of_items[4])
    elif item_name == items_in_store[5]:
        print(price_of_items[5])
    elif item_name == items_in_store[6]:
        print(price_of_items[6])
    elif item_name == items_in_store[7]:
        print(price_of_items[7])
    else:
        print("search not found")
elif class_search == "b":
    print("The class Beverages available are;")
    print('\nmilk\nmilo\ncoke\nfanta\npepsi\nyoughut\nsoya\nthree_crowns')
    item_name = input("Enter item_name:")
    items_in_store = ["milk", "milo", "fanta", "coke", "pepsi", "youghut", "soya", "three_crowns"]
    print("price in #")
    price_of_items = [170, 670, 130, 650, 1870, 500, 2000, 1500]

    if item_name == items_in_store[0] :
        print(price_of_items[0])
    elif item_name == items_in_store[1]:
        print(price_of_items[1])
    elif item_name == items_in_store[2]:
        print(price_of_items[2])
    elif item_name == items_in_store[3]:
        print(price_of_items[3])
    elif item_name == items_in_store[4]:
        print(price_of_items[4])
    elif item_name == items_in_store[5]:
        print(price_of_items[5])
    elif item_name == items_in_store[6]:
        print(price_of_items[6])
    elif item_name == items_in_store[7]:
        print(price_of_items[7])
    else:
        print("search not found")

elif class_search == "c":
    print("The class Drinks and wines available are;")
    print('\nRed wine\nsmirnoff\nblack bullet\nblue bullet\norigin\nodogwu bitters\ncann malt\nsosa\nfearless\nterminator\nbottle water\neva\nrose\nred label')
    item_name = input("Enter item_name:")
    items_in_store = ["Red wine", "smirnoff", "black bullet", "blue bullet", "origin", "odogwu bitters", "cann malt", "sosa", "fearless", "terminator", "bottle water", "eva","rose","red label"]
    print("price in #")
    price_of_items = [10000, 2500, 900, 700, 8770, 5045, 1500, 2000, 6700, 9050,4500,7000,2800,23500]
    if item_name == items_in_store[0]:
        print(price_of_items[0])
    elif item_name == items_in_store[1]:
        print(price_of_items[1])
    elif item_name == items_in_store[2]:
        print(price_of_items[2])
    elif item_name == items_in_store[3]:
        print(price_of_items[3])
    elif item_name == items_in_store[4]:
        print(price_of_items[4])
    elif item_name == items_in_store[5]:
        print(price_of_items[5])
    elif item_name == items_in_store[6]:
        print(price_of_items[6])
    elif item_name == items_in_store[7]:
        print(price_of_items[7])
    elif item_name == items_in_store[8]:
        print(price_of_items[8])
    elif item_name == items_in_store[9]:
        print(price_of_items[9])
    elif item_name == items_in_store[10]:
        print(price_of_items[10])
    elif item_name == items_in_store[11]:
        print(price_of_items[11])
    elif item_name == items_in_store[12]:
        print(price_of_items[12])
    elif item_name == items_in_store[13]:
        print(price_of_items[13])
    elif item_name == items_in_store[14]:
        print(price_of_items[14])
    else:
        print("search not found")
elif class_search == "d":
    print("The class drugs available are;")
    print('\nparacetamol\nsilvoloratidine\nampiclox\nflagyl\nchloroquine\npiritin\nvitamin-c\nibuprufen\ntramadol\npanadol')

    item_name = input("Enter item_name:")
    items_in_store = ["paracetamol", "silvoloratidine", "ampiclox", "flagyl", "chloroquine", "piritin", "vitamin-c", "ibuprufen", "tramadol", "panadol"]
    print("price in #")
    price_of_items = [150, 780, 500, 430, 320, 200, 210, 250, 1800, 210]

    if item_name == items_in_store[0]:
        print(price_of_items[0])
    elif item_name == items_in_store[1]:
        print(price_of_items[1])
    elif item_name == items_in_store[2]:
        print(price_of_items[2])
    elif item_name == items_in_store[3]:
        print(price_of_items[3])
    elif item_name == items_in_store[4]:
        print(price_of_items[4])
    elif item_name == items_in_store[5]:
        print(price_of_items[5])
    elif item_name == items_in_store[6]:
        print(price_of_items[6])
    elif item_name == items_in_store[7]:
        print(price_of_items[7])
    elif item_name == items_in_store[8]:
        print(price_of_items[8])
    elif item_name == items_in_store[9]:
        print(price_of_items[9])
    else:
        print("search not found")

elif class_search == "e":
    print("The items present in all are:")
    g = {"meat_pie":100, "egg_roll":233,"buns":123,"samosa":567,"doughnut":870,"puff_puff":545,"bread":1000,"sharwarma":1900,
         "milk":170, "milo":670, "coke":130, "fanta":650, "pepsi":1870, "youghut":500,"soya":2000,"three_crowns":1500,
         "Red wine":10000, "smirnoff":2500, "black bullet":900, "blue bullet":700, "origin":8770, "odogwu bitters":5045, "cann malt":1500, "sosa":2000, "fearless":6700, "terminator":9050, "bottle water":4500, "eva":7000,"rose":2800,"red label":23500,
         "paracetamol":150, "silvoloratidine":780, "ampiclox":500, "flagyl":430, "chloroquine":320, "piritin":200, "vitamin-c":210, "ibuprufen":250,"tramadol":1800,"panadol":210}
    search_in_all = input("enter item:")
    if search_in_all == "meat_pie":
        print(g.get("meat_pie"))
    elif search_in_all == "egg_roll":
        print(g.get("egg_roll"))
    elif search_in_all == "buns":
        print(g.get("buns"))
    elif search_in_all == "samosa":
        print(g.get("samosa"))
    elif search_in_all == "doughnut":
        print(g.get("doughnut"))
    elif search_in_all == "puff_puff":
        print(g.get("puff_puff"))
    elif search_in_all == "bread":
        print(g.get("bread"))
    elif search_in_all == "sharwarma":
        print(g.get("sharwarma"))
    elif search_in_all == "milk":
        print(g.get("milk"))
    elif search_in_all == "milo":
        print(g.get("milo"))
    elif search_in_all == "coke":
        print(g.get("coke"))
    elif search_in_all == "fanta":
        print(g.get("fanta"))
    elif search_in_all == "pepsi":
        print(g.get("pepsi"))
    elif search_in_all == "youghut":
        print(g.get("youghut"))
    elif search_in_all == "soya":
        print(g.get("soya"))
    elif search_in_all == "three_crowns":
        print(g.get("three_crowns"))
    elif search_in_all == "Red wine":
        print(g.get("Red wine"))
    elif search_in_all == "smirnoff":
        print(g.get("smirnoff"))
    elif search_in_all == "black bullet":
        print(g.get("black bullet"))
    elif search_in_all == "blue bullet":
        print(g.get("blue bullet"))
    elif search_in_all == "origin":
        print(g.get("origin"))
    elif search_in_all == "odogwu bitters":
        print(g.get("odogwu bitters"))
    elif search_in_all == "cann malt":
        print(g.get("cann malt"))
    elif search_in_all == "sosa":
        print(g.get("sosa"))
    elif search_in_all == "faerless":
        print(g.get("fearless"))
    elif search_in_all == "terminator":
        print(g.get("terminator"))
    elif search_in_all == "bottle water":
        print(g.get("bottle water"))
    elif search_in_all == "eva":
        print(g.get("eva"))
    elif search_in_all == "rose":
        print(g.get("rose"))
    elif search_in_all == "red label":
        print(g.get("red label"))
    elif search_in_all == "paracetamol":
        print(g.get("paracetamol"))
    elif search_in_all == "silvoloratidine":
        print(g.get("silvoloratidine"))
    elif search_in_all == "ampiclox":
        print(g.get("ampiclox"))
    elif search_in_all == "flagyl":
        print(g.get("flagyl"))
    elif search_in_all == "chloroquine":
        print(g.get("chloroquine"))
    elif search_in_all == "piritin":
        print(g.get("piritin"))
    elif search_in_all == "vitamin-c":
        print(g.get("vitamin-c"))
    elif search_in_all == "ibuprufen":
        print(g.get("ibuprufen"))
    elif search_in_all == "tramadol":
        print(g.get("tramadol"))
    elif search_in_all == "panadol":
        print(g.get("panadol"))
    else:
        print("search not found!!!")
# Out:
# Welcome to tolubass supermarket
# SEARCH THE PRICE OF ANY ITEM
# a.clas Snacks
# b.clas Beverages
# c.clas Drinks and wines
# d.clas Drugs
# e.SEARCH ALL
# Enter the class/category of the item:(a/b/c/d/e):e
# The items present in all are:
# enter item:milk
# 170
